# %% [markdown]
# # Practice Lab: Linear Regression
#
# Welcome to your first practice lab! In this lab, you will implement linear regression with one variable to predict profits for a restaurant franchise.
#
#
# # Outline
# - [ 1 - Packages ](#1)
# - [ 2 - Linear regression with one variable ](#2)
#   - [ 2.1 Problem Statement](#2.1)
#   - [ 2.2  Dataset](#2.2)
#   - [ 2.3 Refresher on linear regression](#2.3)
#   - [ 2.4  Compute Cost](#2.4)
#     - [ Exercise 1](#ex01)
#   - [ 2.5 Gradient descent ](#2.5)
#     - [ Exercise 2](#ex02)
#   - [ 2.6 Learning parameters using batch gradient descent ](#2.6)

# %% [markdown]
# _**NOTE:** To prevent errors from the autograder, you are not allowed to edit or delete non-graded cells in this notebook . Please also refrain from adding any new cells.
# **Once you have passed this assignment** and want to experiment with any of the non-graded code, you may follow the instructions at the bottom of this notebook._

# %% [markdown]
# <a name="1"></a>
# ## 1 - Packages
#
# First, let's run the cell below to import all the packages that you will need during this assignment.
# - [numpy](www.numpy.org) is the fundamental package for working with matrices in Python.
# - [matplotlib](http://matplotlib.org) is a famous library to plot graphs in Python.
# - ``utils.py`` contains helper functions for this assignment. You do not need to modify code in this file.

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *
import copy
import math
import copy
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from utils import *
#       4 import copy
#       5 import math
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# ## 2 -  Problem Statement
#
# Suppose you are the CEO of a restaurant franchise and are considering different cities for opening a new outlet.
# - You would like to expand your business to cities that may give your restaurant higher profits.
# - The chain already has restaurants in various cities and you have data for profits and populations from the cities.
# - You also have data on cities that are candidates for a new restaurant.
#     - For these cities, you have the city population.
#
# Can you use the data to help you identify which cities may potentially give your business higher profits?
#
# ## 3 - Dataset
#
# You will start by loading the dataset for this task.
# - The `load_data()` function shown below loads the data into variables `x_train` and `y_train`
#   - `x_train` is the population of a city
#   - `y_train` is the profit of a restaurant in that city. A negative value for profit indicates a loss.
#   - Both `X_train` and `y_train` are numpy arrays.

# %%
# load the dataset
x_train, y_train = load_data()

# %%
# load the dataset
import csv
import pandas as pd

# Replace 'your_file.txt' with the actual file path
with open('ex1data1.txt', 'r') as file:
    # Create a CSV reader object    
    reader = csv.reader(file, delimiter=',')
    
    # Read the data into a list
    data = [row for row in reader]
    
    df = pd.DataFrame(data,columns=['data'])
    
    df[['x_train', 'y_train']] = df['data'].str.split('\t', expand=True)

# Drop the original 'data' column
    df.drop(columns=['data'], inplace=True)

# Convert the 'x_train' and 'y_train' columns to numeric type
    df['x_train'] = pd.to_numeric(df['x_train'])
    df['y_train'] = pd.to_numeric(df['y_train'])

# Now, df contains your data with the first column split into two separate columns
    print(df)
    

# Parse the string data
    x_train = df['x_train'].to_numpy()
    y_train = df['y_train'].to_numpy()
# Now, 'data' is a list containing the rows of your datasheet

#write your code here to load the dataset! (The previous block does not work correctly)
# Out:
#     x_train   y_train
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]

# %% [markdown]
# #### View the variables
# Before starting on any task, it is useful to get more familiar with your dataset.
# - A good place to start is to just print out each variable and see what it contains.
#
# The code below prints the variable `x_train` and the type of the variable.

# %%
# print x_train
print("Type of x_train:",type(x_train))
print("First five elements of x_train are:\n", x_train[:5])
# Out:
# Type of x_train: <class 'numpy.ndarray'>
# First five elements of x_train are:
#  [6.1101 5.5277 8.5186 7.0032 5.8598]

# %% [markdown]
# `x_train` is a numpy array that contains decimal values that are all greater than zero.
# - These values represent the city population times 10,000
# - For example, 6.1101 means that the population for that city is 61,101
#
# Now, let's print `y_train`

# %%
# print y_train
print("Type of y_train:",type(y_train))
print("First five elements of y_train are:\n", y_train[:5])
# Out:
# Type of y_train: <class 'numpy.ndarray'>
# First five elements of y_train are:
#  [17.592   9.1302 13.662  11.854   6.8233]

# %% [markdown]
# Similarly, `y_train` is a numpy array that has decimal values, some negative, some positive.
# - These represent your restaurant's average monthly profits in each city, in units of \$10,000.
#   - For example, 17.592 represents \$175,920 in average monthly profits for that city.
#   - -2.6807 represents -\$26,807 in average monthly loss for that city.

# %% [markdown]
# #### Check the dimensions of your variables
#
# Another useful way to get familiar with your data is to view its dimensions.
#
# Please print the shape of `x_train` and `y_train` and see how many training examples you have in your dataset.

# %%
print ('The shape of x_train is:', x_train.shape)
print ('The shape of y_train is: ', y_train.shape)
print ('Number of training examples (m):', len(x_train))
# Out:
# The shape of x_train is: (97,)
# The shape of y_train is:  (97,)
# Number of training examples (m): 97

# %% [markdown]
# The city population array has 97 data points, and the monthly average profits also has 97 data points. These are NumPy 1D arrays.

# %% [markdown]
# #### Visualize your data
#
# It is often useful to understand the data by visualizing it.
# - For this dataset, you can use a scatter plot to visualize the data, since it has only two properties to plot (profit and population).
# - Many other problems that you will encounter in real life have more than two properties (for example, population, average household income, monthly profits, monthly sales).When you have more than two properties, you can still use a scatter plot to see the relationship between each pair of properties.

# %%
# Create a scatter plot of the data. To change the markers to red "x",
# we used the 'marker' and 'c' parameters
plt.scatter(x_train, y_train, marker='x', c='r') 

# Set the title
plt.title("Profits vs. Population per city")
# Set the y-axis label
plt.ylabel('Profit in $10,000')
# Set the x-axis label
plt.xlabel('Population of City in 10,000s')
plt.show()

# %% [markdown]
# Your goal is to build a linear regression model to fit this data.
# - With this model, you can then input a new city's population, and have the model estimate your restaurant's potential monthly profits for that city.

# %% [markdown]
# <a name="4"></a>
# ## 4 - Refresher on linear regression
#
# In this practice lab, you will fit the linear regression parameters $(w,b)$ to your dataset.
# - The model function for linear regression, which is a function that maps from `x` (city population) to `y` (your restaurant's monthly profit for that city) is represented as
#     $$f_{w,b}(x) = wx + b$$
#
#
# - To train a linear regression model, you want to find the best $(w,b)$ parameters that fit your dataset.
#
#     - To compare how one choice of $(w,b)$ is better or worse than another choice, you can evaluate it with a cost function $J(w,b)$
#       - $J$ is a function of $(w,b)$. That is, the value of the cost $J(w,b)$ depends on the value of $(w,b)$.
#
#     - The choice of $(w,b)$ that fits your data the best is the one that has the smallest cost $J(w,b)$.
#
#
# - To find the values $(w,b)$ that gets the smallest possible cost $J(w,b)$, you can use a method called **gradient descent**.
#   - With each step of gradient descent, your parameters $(w,b)$ come closer to the optimal values that will achieve the lowest cost $J(w,b)$.
#
#
# - The trained linear regression model can then take the input feature $x$ (city population) and output a prediction $f_{w,b}(x)$ (predicted monthly profit for a restaurant in that city).

# %% [markdown]
# <a name="5"></a>
# ## 5 - Compute Cost
#
# Gradient descent involves repeated steps to adjust the value of your parameter $(w,b)$ to gradually get a smaller and smaller cost $J(w,b)$.
# - At each step of gradient descent, it will be helpful for you to monitor your progress by computing the cost $J(w,b)$ as $(w,b)$ gets updated.
# - In this section, you will implement a function to calculate $J(w,b)$ so that you can check the progress of your gradient descent implementation.
#
# #### Cost function
# As you may recall from the lecture, for one variable, the cost function for linear regression $J(w,b)$ is defined as
#
# $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2$$
#
# - You can think of $f_{w,b}(x^{(i)})$ as the model's prediction of your restaurant's profit, as opposed to $y^{(i)}$, which is the actual profit that is recorded in the data.
# - $m$ is the number of training examples in the dataset
#
# #### Model prediction
#
# - For linear regression with one variable, the prediction of the model $f_{w,b}$ for an example $x^{(i)}$ is representented as:
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b$$
#
# This is the equation for a line, with an intercept $b$ and a slope $w$
#
# #### Implementation
#
# Please complete the `compute_cost()` function below to compute the cost $J(w,b)$.

# %% [markdown]
# <a name="ex01"></a>
# ### Exercise 1
#
# Complete the `compute_cost` below to:
#
# * Iterate over the training examples, and for each example, compute:
#     * The prediction of the model for that example
#     $$
#     f_{wb}(x^{(i)}) =  wx^{(i)} + b
#     $$
#
#     * The cost for that example  $$cost^{(i)} =  (f_{wb} - y^{(i)})^2$$
#
#
# * Return the total cost over all examples
# $$J(\mathbf{w},b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} cost^{(i)}$$
#   * Here, $m$ is the number of training examples and $\sum$ is the summation operator
#
# If you get stuck, you can check out the hints presented after the cell below to help you with the implementation.

# %%
# UNQ_C1
# GRADED FUNCTION: compute_cost

def compute_cost(x, y, w, b): 
    """
    Computes the cost function for linear regression.
    
    Args:
        x (ndarray): Shape (m,) Input to the model (Population of cities) 
        y (ndarray): Shape (m,) Label (Actual profits for the cities)
        w, b (scalar): Parameters of the model
    
    Returns
        total_cost (float): The cost of using w,b as the parameters for linear regression
               to fit the data points in x and y
    """
    # number of training examples
    m = x.shape[0] 
    
    # You need to return this variable correctly
    total_cost = 0
    
    ### START CODE HERE ###
    
    for i in range(m):
        # Prediction of the model for the current example
        prediction = w * x[i] + b

        # Cost for the current example
        cost_i = (prediction - y[i]) ** 2

        # Accumulate the cost
        total_cost += cost_i
    ### END CODE HERE ### 
    
    # Calculate the average cost
    total_cost = total_cost / (2 * m)
    ### END CODE HERE ### 

    return total_cost

# %% [markdown]
# <details>
#   <summary><font size="3" color="darkgreen"><b>Click for hints</b></font></summary>
#
#
#    * You can represent a summation operator eg: $h = \sum\limits_{i = 0}^{m-1} 2i$ in code as follows:
#
#     ```python
#     h = 0
#     for i in range(m):
#         h = h + 2*i
#     ```
#
#    * In this case, you can iterate over all the examples in `x` using a for loop and add the `cost` from each iteration to a variable (`cost_sum`) initialized outside the loop.
#
#    * Then, you can return the `total_cost` as `cost_sum` divided by `2m`.
#    * If you are new to Python, please check that your code is properly indented with consistent spaces or tabs. Otherwise, it might produce a different output or raise an `IndentationError: unexpected indent` error. You can refer to [this topic](https://community.deeplearning.ai/t/indentation-in-python-indentationerror-unexpected-indent/159398) in our community for details.
#
#     <details>
#           <summary><font size="2" color="darkblue"><b> Click for more hints</b></font></summary>
#
#     * Here's how you can structure the overall implementation for this function
#
#     ```python
#     def compute_cost(x, y, w, b):
#         # number of training examples
#         m = x.shape[0]
#
#         # You need to return this variable correctly
#         total_cost = 0
#
#         ### START CODE HERE ###
#         # Variable to keep track of sum of cost from each example
#         cost_sum = 0
#
#         # Loop over training examples
#         for i in range(m):
#             # Your code here to get the prediction f_wb for the ith example
#             f_wb =
#             # Your code here to get the cost associated with the ith example
#             cost =
#
#             # Add to sum of cost for each example
#             cost_sum = cost_sum + cost
#
#         # Get the total cost as the sum divided by (2*m)
#         total_cost = (1 / (2 * m)) * cost_sum
#         ### END CODE HERE ###
#
#         return total_cost
#     ```
#
#     * If you're still stuck, you can check the hints presented below to figure out how to calculate `f_wb` and `cost`.
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate f_wb</b></font></summary>
#            &emsp; &emsp; For scalars $a$, $b$ and $c$ (<code>x[i]</code>, <code>w</code> and <code>b</code> are all scalars), you can calculate the equation $h = ab + c$ in code as <code>h = a * b + c</code>
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; More hints to calculate f</b></font></summary>
#                &emsp; &emsp; You can compute f_wb as <code>f_wb = w * x[i] + b </code>
#            </details>
#     </details>
#
#      <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate cost</b></font></summary>
#           &emsp; &emsp; You can calculate the square of a variable z as z**2
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; More hints to calculate cost</b></font></summary>
#               &emsp; &emsp; You can compute cost as <code>cost = (f_wb - y[i]) ** 2</code>
#           </details>
#     </details>
#
#     </details>
#
# </details>

# %% [markdown]
# You can check if your implementation was correct by running the following test code:

# %%
# Compute cost with some initial values for paramaters w, b
initial_w = 2
initial_b = 1

cost = compute_cost(x_train, y_train, initial_w, initial_b)
print(type(cost))
print(f'Cost at initial w: {cost:.3f}')

# Public tests
from public_tests import *
compute_cost_test(compute_cost)
# Out:
# Average total cost: 75.20338497891959
# <class 'numpy.float64'>
# Cost at initial w: 75.203
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 10
#       7 print(f'Cost at initial w: {cost:.3f}')
#       9 # Public tests
# ---> 10 from public_tests import *
#      11 compute_cost_test(compute_cost)
#
# ModuleNotFoundError: No module named 'public_tests'

# %% [markdown]
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b>Cost at initial w:<b> 75.203 </td>
#   </tr>
# </table>

# %% [markdown]
# <a name="6"></a>
# ## 6 - Gradient descent
#
# In this section, you will implement the gradient for parameters $w, b$ for linear regression.

# %% [markdown]
# As described in the lecture videos, the gradient descent algorithm is:
#
# $$\begin{align*}& \text{repeat until convergence:} \; \lbrace \newline \; & \phantom {0000} b := b -  \alpha \frac{\partial J(w,b)}{\partial b} \newline       \; & \phantom {0000} w := w -  \alpha \frac{\partial J(w,b)}{\partial w} \tag{1}  \; &
# \newline & \rbrace\end{align*}$$
#
# where, parameters $w, b$ are both updated simultaniously and where
# $$
# \frac{\partial J(w,b)}{\partial b}  = \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)}) \tag{2}
# $$
# $$
# \frac{\partial J(w,b)}{\partial w}  = \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) -y^{(i)})x^{(i)} \tag{3}
# $$
# * m is the number of training examples in the dataset
#
#
# *  $f_{w,b}(x^{(i)})$ is the model's prediction, while $y^{(i)}$, is the target value
#
#
# You will implement a function called `compute_gradient` which calculates $\frac{\partial J(w)}{\partial w}$, $\frac{\partial J(w)}{\partial b}$

# %% [markdown]
# <a name="ex02"></a>
# ### Exercise 2
#
# Please complete the `compute_gradient` function to:
#
# * Iterate over the training examples, and for each example, compute:
#     * The prediction of the model for that example
#     $$
#     f_{wb}(x^{(i)}) =  wx^{(i)} + b
#     $$
#
#     * The gradient for the parameters $w, b$ from that example
#         $$
#         \frac{\partial J(w,b)}{\partial b}^{(i)}  =  (f_{w,b}(x^{(i)}) - y^{(i)})
#         $$
#         $$
#         \frac{\partial J(w,b)}{\partial w}^{(i)}  =  (f_{w,b}(x^{(i)}) -y^{(i)})x^{(i)}
#         $$
#
#
# * Return the total gradient update from all the examples
#     $$
#     \frac{\partial J(w,b)}{\partial b}  = \frac{1}{m} \sum\limits_{i = 0}^{m-1} \frac{\partial J(w,b)}{\partial b}^{(i)}
#     $$
#
#     $$
#     \frac{\partial J(w,b)}{\partial w}  = \frac{1}{m} \sum\limits_{i = 0}^{m-1} \frac{\partial J(w,b)}{\partial w}^{(i)}
#     $$
#   * Here, $m$ is the number of training examples and $\sum$ is the summation operator
#
# If you get stuck, you can check out the hints presented after the cell below to help you with the implementation.

# %%
# UNQ_C2
# GRADED FUNCTION: compute_gradient

def compute_gradient(x, y, w, b): 
    """
    Computes the gradient for linear regression 
    Args:
      x (ndarray): Shape (m,) Input to the model (Population of cities) 
      y (ndarray): Shape (m,) Label (Actual profits for the cities)
      w, b (scalar): Parameters of the model  
    Returns
      dj_dw (scalar): The gradient of the cost w.r.t. the parameters w
      dj_db (scalar): The gradient of the cost w.r.t. the parameter b     
     """
    
    # Number of training examples
    m = x.shape[0]
    
    # You need to return the following variables correctly
    dj_dw = 0
    dj_db = 0
    
    ### START CODE HERE ###
    for i in range(m):
        # Prediction of the model for the current example
        prediction = w * x[i] + b

        # Gradient for the parameter w from the current example
        dj_dw += (prediction - y[i]) * x[i]

        # Gradient for the parameter b from the current example
        dj_db += (prediction - y[i])

    # Average the gradients over all examples
    dj_dw /= m
    dj_db /= m
    ### END CODE HERE ### 
        
    return dj_dw, dj_db

# %% [markdown]
# <details>
#   <summary><font size="3" color="darkgreen"><b>Click for hints</b></font></summary>
#
#    * You can represent a summation operator eg: $h = \sum\limits_{i = 0}^{m-1} 2i$ in code as follows:
#
#    ```python
#     h = 0
#     for i in range(m):
#         h = h + 2*i
#    ```
#
#    * In this case, you can iterate over all the examples in `x` using a for loop and for each example, keep adding the gradient from that example to the variables `dj_dw` and `dj_db` which are initialized outside the loop.
#
#    * Then, you can return `dj_dw` and `dj_db` both divided by `m`.
#     <details>
#           <summary><font size="2" color="darkblue"><b> Click for more hints</b></font></summary>
#
#     * Here's how you can structure the overall implementation for this function
#
#     ```python
#     def compute_gradient(x, y, w, b):
#         """
#         Computes the gradient for linear regression
#         Args:
#           x (ndarray): Shape (m,) Input to the model (Population of cities)
#           y (ndarray): Shape (m,) Label (Actual profits for the cities)
#           w, b (scalar): Parameters of the model
#         Returns
#           dj_dw (scalar): The gradient of the cost w.r.t. the parameters w
#           dj_db (scalar): The gradient of the cost w.r.t. the parameter b
#         """
#
#         # Number of training examples
#         m = x.shape[0]
#
#         # You need to return the following variables correctly
#         dj_dw = 0
#         dj_db = 0
#
#         ### START CODE HERE ###
#         # Loop over examples
#         for i in range(m):
#             # Your code here to get prediction f_wb for the ith example
#             f_wb =
#
#             # Your code here to get the gradient for w from the ith example
#             dj_dw_i =
#
#             # Your code here to get the gradient for b from the ith example
#             dj_db_i =
#
#             # Update dj_db : In Python, a += 1  is the same as a = a + 1
#             dj_db += dj_db_i
#
#             # Update dj_dw
#             dj_dw += dj_dw_i
#
#         # Divide both dj_dw and dj_db by m
#         dj_dw = dj_dw / m
#         dj_db = dj_db / m
#         ### END CODE HERE ###
#
#         return dj_dw, dj_db
#     ```
#
#     * If you're still stuck, you can check the hints presented below to figure out how to calculate `f_wb` and `cost`.
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate f_wb</b></font></summary>
#            &emsp; &emsp; You did this in the previous exercise! For scalars $a$, $b$ and $c$ (<code>x[i]</code>, <code>w</code> and <code>b</code> are all scalars), you can calculate the equation $h = ab + c$ in code as <code>h = a * b + c</code>
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; More hints to calculate f</b></font></summary>
#                &emsp; &emsp; You can compute f_wb as <code>f_wb = w * x[i] + b </code>
#            </details>
#     </details>
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate dj_dw_i</b></font></summary>
#            &emsp; &emsp; For scalars $a$, $b$ and $c$ (<code>f_wb</code>, <code>y[i]</code> and <code>x[i]</code> are all scalars), you can calculate the equation $h = (a - b)c$ in code as <code>h = (a-b)*c</code>
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; More hints to calculate f</b></font></summary>
#                &emsp; &emsp; You can compute dj_dw_i as <code>dj_dw_i = (f_wb - y[i]) * x[i] </code>
#            </details>
#     </details>
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate dj_db_i</b></font></summary>
#              &emsp; &emsp; You can compute dj_db_i as <code> dj_db_i = f_wb - y[i] </code>
#     </details>
#
#     </details>
#
# </details>

# %% [markdown]
# Run the cells below to check your implementation of the `compute_gradient` function with two different initializations of the parameters $w$,$b$.

# %%
# Compute and display gradient with w initialized to zeroes
initial_w = 0
initial_b = 0

tmp_dj_dw, tmp_dj_db = compute_gradient(x_train, y_train, initial_w, initial_b)
print('Gradient at initial w, b (zeros):', tmp_dj_dw, tmp_dj_db)

compute_gradient_test(compute_gradient)
# Out:
# Gradient at initial w, b (zeros): -65.32884974555672 -5.83913505154639
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       5 tmp_dj_dw, tmp_dj_db = compute_gradient(x_train, y_train, initial_w, initial_b)
#       6 print('Gradient at initial w, b (zeros):', tmp_dj_dw, tmp_dj_db)
# ----> 8 compute_gradient_test(compute_gradient)
#
# NameError: name 'compute_gradient_test' is not defined

# %% [markdown]
# Now let's run the gradient descent algorithm implemented above on our dataset.
#
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b>Gradient at initial , b (zeros)<b></td>
#     <td> -65.32884975 -5.83913505154639</td>
#   </tr>
# </table>

# %%
# Compute and display cost and gradient with non-zero w
test_w = 0.2
test_b = 0.2
tmp_dj_dw, tmp_dj_db = compute_gradient(x_train, y_train, test_w, test_b)

print('Gradient at test w, b:', tmp_dj_dw, tmp_dj_db)
# Out:
# Gradient at test w, b: -47.41610118114435 -4.007175051546391

# %% [markdown]
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b>Gradient at test w<b></td>
#     <td> -47.41610118 -4.007175051546391</td>
#   </tr>
# </table>

# %% [markdown]
# <a name="2.6"></a>
# ### 2.6 Learning parameters using batch gradient descent
#
# You will now find the optimal parameters of a linear regression model by using batch gradient descent. Recall batch refers to running all the examples in one iteration.
# - You don't need to implement anything for this part. Simply run the cells below.
#
# - A good way to verify that gradient descent is working correctly is to look
# at the value of $J(w,b)$ and check that it is decreasing with each step.
#
# - Assuming you have implemented the gradient and computed the cost correctly and you have an appropriate value for the learning rate alpha, $J(w,b)$ should never increase and should converge to a steady value by the end of the algorithm.

# %%
def gradient_descent(x, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters): 
    """
    Performs batch gradient descent to learn theta. Updates theta by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      x :    (ndarray): Shape (m,)
      y :    (ndarray): Shape (m,)
      w_in, b_in : (scalar) Initial values of parameters of the model
      cost_function: function to compute cost
      gradient_function: function to compute the gradient
      alpha : (float) Learning rate
      num_iters : (int) number of iterations to run gradient descent
    Returns
      w : (ndarray): Shape (1,) Updated values of parameters of the model after
          running gradient descent
      b : (scalar)                Updated value of parameter of the model after
          running gradient descent
    """
    
    # number of training examples
    m = len(x)
    
    # An array to store cost J and w's at each iteration — primarily for graphing later
    J_history = []
    w_history = []
    w = copy.deepcopy(w_in)  #avoid modifying global w within function
    b = b_in
    
    for i in range(num_iters):

        # Calculate the gradient and update the parameters
        dj_dw, dj_db = gradient_function(x, y, w, b )  

        # Update Parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw               
        b = b - alpha * dj_db               

        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion 
            cost =  cost_function(x, y, w, b)
            J_history.append(cost)

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters/10) == 0:
            w_history.append(w)
            print(f"Iteration {i:4}: Cost {float(J_history[-1]):8.2f}   ")
        
    return w, b, J_history, w_history #return w and J,w history for graphing

# %% [markdown]
# Now let's run the gradient descent algorithm above to learn the parameters for our dataset.

# %%
# initialize fitting parameters. Recall that the shape of w is (n,)
initial_w = 0.
initial_b = 0.

# some gradient descent settings
iterations = 1500
alpha = 0.01

w,b,_,_ = gradient_descent(x_train ,y_train, initial_w, initial_b, 
                     compute_cost, compute_gradient, alpha, iterations)
print("w,b found by gradient descent:", w, b)
# Out:
# Average total cost: 6.737190464870008
# Iteration    0: Cost     6.74
# Average total cost: 5.931593568604957
# Average total cost: 5.901154707081387
# Average total cost: 5.89522858644422
# Average total cost: 5.890094943117333
# Average total cost: 5.885004158443646
# Average total cost: 5.879932480491416
# Average total cost: 5.874879094762575
# Average total cost: 5.8698439118063845
# Average total cost: 5.8648268653129305
# Average total cost: 5.8598278899321805
# Average total cost: 5.85484692057229
# Average total cost: 5.849883892376585
# Average total cost: 5.844938740722036
# Average total cost: 5.840011401218365
# Average total cost: 5.835101809707228
# Average total cost: 5.830209902261389
# Average total cost: 5.825335615183866
# Average total cost: 5.820478885007098
# Average total cost: 5.8156396484921515
# Average total cost: 5.81081784262787
# Average total cost: 5.806013404630042
# Average total cost: 5.801226271940627
# Average total cost: 5.796456382226899
# Average total cost: 5.791703673380652
# Average total cost: 5.786968083517397
# Average total cost: 5.782249550975539
# Average total cost: 5.777548014315598
# Average total cost: 5.772863412319381
# Average total cost: 5.768195683989212
# Average total cost: 5.76354476854712
# Average total cost: 5.758910605434049
# Average total cost: 5.754293134309077
# Average total cost: 5.7496922950486296
# Average total cost: 5.745108027745686
# Average total cost: 5.740540272709014
# Average total cost: 5.735988970462384
# Average total cost: 5.7314540617437935
# Average total cost: 5.7269354875047025
# Average total cost: 5.722433188909259
# Average total cost: 5.717947107333528
# Average total cost: 5.713477184364749
# Average total cost: 5.709023361800547
# Average total cost: 5.704585581648199
# Average total cost: 5.700163786123851
# Average total cost: 5.695757917651815
# Average total cost: 5.69136791886375
# Average total cost: 5.6869937325979825
# Average total cost: 5.6826353018987055
# Average total cost: 5.6782925700152935
# Average total cost: 5.673965480401505
# Average total cost: 5.669653976714796
# Average total cost: 5.665358002815552
# Average total cost: 5.661077502766383
# Average total cost: 5.656812420831358
# Average total cost: 5.6525627014753335
# Average total cost: 5.648328289363183
# Average total cost: 5.6441091293590935
# Average total cost: 5.639905166525854
# Average total cost: 5.635716346124134
# Average total cost: 5.6315426136117726
# Average total cost: 5.627383914643053
# Average total cost: 5.623240195068026
# Average total cost: 5.6191114009317795
# Average total cost: 5.6149974784737395
# Average total cost: 5.610898374126983
# Average total cost: 5.606814034517532
# Average total cost: 5.6027444064636525
# Average total cost: 5.598689436975159
# Average total cost: 5.594649073252758
# Average total cost: 5.590623262687323
# Average total cost: 5.586611952859217
# Average total cost: 5.582615091537621
# Average total cost: 5.578632626679853
# Average total cost: 5.574664506430677
# Average total cost: 5.570710679121647
# Average total cost: 5.566771093270404
# Average total cost: 5.562845697580047
# Average total cost: 5.558934440938444
# Average total cost: 5.555037272417541
# Average total cost: 5.551154141272755
# Average total cost: 5.547284996942256
# Average total cost: 5.543429789046351
# Average total cost: 5.539588467386808
# Average total cost: 5.535760981946204
# Average total cost: 5.531947282887273
# Average total cost: 5.528147320552271
# Average total cost: 5.524361045462307
# Average total cost: 5.520588408316713
# Average total cost: 5.516829359992401
# Average total cost: 5.513083851543223
# Average total cost: 5.509351834199334
# Average total cost: 5.5056332593665385
# Average total cost: 5.501928078625699
# Average total cost: 5.498236243732062
# Average total cost: 5.494557706614665
# Average total cost: 5.490892419375678
# Average total cost: 5.487240334289807
# Average total cost: 5.483601403803651
# Average total cost: 5.479975580535111
# Average total cost: 5.476362817272741
# Average total cost: 5.472763066975153
# Average total cost: 5.469176282770398
# Average total cost: 5.465602417955358
# Average total cost: 5.462041425995138
# Average total cost: 5.4584932605224585
# Average total cost: 5.454957875337047
# Average total cost: 5.451435224405054
# Average total cost: 5.447925261858425
# Average total cost: 5.444427941994334
# Average total cost: 5.440943219274568
# Average total cost: 5.437471048324931
# Average total cost: 5.434011383934687
# Average total cost: 5.430564181055921
# Average total cost: 5.4271293948029875
# Average total cost: 5.423706980451917
# Average total cost: 5.420296893439838
# Average total cost: 5.416899089364381
# Average total cost: 5.413513523983123
# Average total cost: 5.410140153212986
# Average total cost: 5.4067789331296945
# Average total cost: 5.403429819967165
# Average total cost: 5.400092770116975
# Average total cost: 5.3967677401277685
# Average total cost: 5.393454686704697
# Average total cost: 5.390153566708864
# Average total cost: 5.386864337156749
# Average total cost: 5.383586955219662
# Average total cost: 5.380321378223177
# Average total cost: 5.377067563646583
# Average total cost: 5.373825469122315
# Average total cost: 5.370595052435429
# Average total cost: 5.367376271523024
# Average total cost: 5.364169084473711
# Average total cost: 5.360973449527068
# Average total cost: 5.3577893250730835
# Average total cost: 5.354616669651634
# Average total cost: 5.351455441951913
# Average total cost: 5.348305600811943
# Average total cost: 5.345167105217981
# Average total cost: 5.34203991430403
# Average total cost: 5.338923987351284
# Average total cost: 5.335819283787603
# Average total cost: 5.332725763186986
# Average total cost: 5.329643385269055
# Average total cost: 5.326572109898499
# Average total cost: 5.323511897084589
# Average total cost: 5.320462706980629
# Average total cost: 5.317424499883462
# Average total cost: 5.314397236232924
# Average total cost: 5.311380876611357
# Iteration  150: Cost     5.31
# Average total cost: 5.308375381743072
# Average total cost: 5.305380712493862
# Average total cost: 5.302396829870465
# Average total cost: 5.2994236950200815
# Average total cost: 5.29646126922985
# Average total cost: 5.2935095139263595
# Average total cost: 5.290568390675126
# Average total cost: 5.287637861180119
# Average total cost: 5.2847178872832306
# Average total cost: 5.281808430963812
# Average total cost: 5.278909454338152
# Average total cost: 5.276020919659002
# Average total cost: 5.27314278931507
# Average total cost: 5.270275025830545
# Average total cost: 5.267417591864591
# Average total cost: 5.264570450210886
# Average total cost: 5.26173356379711
# Average total cost: 5.2589068956844836
# Average total cost: 5.256090409067275
# Average total cost: 5.253284067272323
# Average total cost: 5.250487833758565
# Average total cost: 5.247701672116554
# Average total cost: 5.244925546067996
# Average total cost: 5.242159419465253
# Average total cost: 5.2394032562909025
# Average total cost: 5.236657020657249
# Average total cost: 5.233920676805869
# Average total cost: 5.231194189107128
# Average total cost: 5.228477522059737
# Average total cost: 5.225770640290267
# Average total cost: 5.223073508552727
# Average total cost: 5.220386091728056
# Average total cost: 5.217708354823696
# Average total cost: 5.215040262973137
# Average total cost: 5.212381781435449
# Average total cost: 5.209732875594843
# Average total cost: 5.207093510960208
# Average total cost: 5.204463653164676
# Average total cost: 5.201843267965148
# Average total cost: 5.199232321241894
# Average total cost: 5.196630778998063
# Average total cost: 5.194038607359261
# Average total cost: 5.19145577257311
# Average total cost: 5.188882241008802
# Average total cost: 5.1863179791566765
# Average total cost: 5.183762953627759
# Average total cost: 5.181217131153349
# Average total cost: 5.178680478584577
# Average total cost: 5.176152962891968
# Average total cost: 5.173634551165023
# Average total cost: 5.1711252106117795
# Average total cost: 5.168624908558405
# Average total cost: 5.166133612448731
# Average total cost: 5.163651289843876
# Average total cost: 5.161177908421788
# Average total cost: 5.158713435976852
# Average total cost: 5.156257840419432
# Average total cost: 5.153811089775505
# Average total cost: 5.151373152186197
# Average total cost: 5.148943995907394
# Average total cost: 5.146523589309324
# Average total cost: 5.144111900876141
# Average total cost: 5.141708899205514
# Average total cost: 5.139314553008235
# Average total cost: 5.136928831107778
# Average total cost: 5.134551702439931
# Average total cost: 5.1321831360523635
# Average total cost: 5.129823101104237
# Average total cost: 5.127471566865795
# Average total cost: 5.125128502717983
# Average total cost: 5.1227938781520095
# Average total cost: 5.120467662768993
# Average total cost: 5.118149826279544
# Average total cost: 5.115840338503369
# Average total cost: 5.113539169368884
# Average total cost: 5.111246288912826
# Average total cost: 5.108961667279849
# Average total cost: 5.106685274722152
# Average total cost: 5.104417081599076
# Average total cost: 5.102157058376735
# Average total cost: 5.099905175627619
# Average total cost: 5.097661404030209
# Average total cost: 5.09542571436861
# Average total cost: 5.0931980775321515
# Average total cost: 5.090978464515023
# Average total cost: 5.088766846415888
# Average total cost: 5.086563194437519
# Average total cost: 5.0843674798863985
# Average total cost: 5.082179674172385
# Average total cost: 5.079999748808298
# Average total cost: 5.077827675409569
# Average total cost: 5.075663425693872
# Average total cost: 5.073506971480756
# Average total cost: 5.071358284691266
# Average total cost: 5.069217337347599
# Average total cost: 5.067084101572703
# Average total cost: 5.06495854958997
# Average total cost: 5.062840653722809
# Average total cost: 5.0607303863943445
# Average total cost: 5.058627720127012
# Average total cost: 5.056532627542232
# Average total cost: 5.054445081360034
# Average total cost: 5.052365054398718
# Average total cost: 5.050292519574479
# Average total cost: 5.048227449901074
# Average total cost: 5.046169818489458
# Average total cost: 5.044119598547441
# Average total cost: 5.042076763379342
# Average total cost: 5.040041286385625
# Average total cost: 5.038013141062577
# Average total cost: 5.03599230100194
# Average total cost: 5.033978739890577
# Average total cost: 5.031972431510143
# Average total cost: 5.029973349736707
# Average total cost: 5.0279814685404585
# Average total cost: 5.025996761985323
# Average total cost: 5.0240192042286695
# Average total cost: 5.022048769520929
# Average total cost: 5.020085432205297
# Average total cost: 5.01812916671737
# Average total cost: 5.016179947584836
# Average total cost: 5.014237749427131
# Average total cost: 5.012302546955105
# Average total cost: 5.010374314970706
# Average total cost: 5.00845302836664
# Average total cost: 5.006538662126046
# Average total cost: 5.004631191322177
# Average total cost: 5.002730591118059
# Average total cost: 5.0008368367662
# Average total cost: 4.998949903608226
# Average total cost: 4.997069767074595
# Average total cost: 4.995196402684253
# Average total cost: 4.993329786044339
# Average total cost: 4.991469892849847
# Average total cost: 4.989616698883302
# Average total cost: 4.987770180014482
# Average total cost: 4.985930312200063
# Average total cost: 4.984097071483333
# Average total cost: 4.982270433993872
# Average total cost: 4.9804503759472345
# Average total cost: 4.978636873644651
# Average total cost: 4.976829903472698
# Average total cost: 4.97502944190303
# Average total cost: 4.973235465492033
# Average total cost: 4.971447950880541
# Average total cost: 4.96966687479352
# Average total cost: 4.967892214039784
# Average total cost: 4.966123945511667
# Average total cost: 4.964362046184745
# Average total cost: 4.962606493117519
# Iteration  300: Cost     4.96
# Average total cost: 4.960857263451132
# Average total cost: 4.959114334409054
# Average total cost: 4.957377683296803
# Average total cost: 4.955647287501641
# Average total cost: 4.953923124492269
# Average total cost: 4.952205171818561
# Average total cost: 4.950493407111239
# Average total cost: 4.948787808081608
# Average total cost: 4.947088352521254
# Average total cost: 4.945395018301758
# Average total cost: 4.943707783374399
# Average total cost: 4.942026625769874
# Average total cost: 4.94035152359803
# Average total cost: 4.938682455047537
# Average total cost: 4.937019398385643
# Average total cost: 4.93536233195787
# Average total cost: 4.933711234187741
# Average total cost: 4.9320660835764984
# Average total cost: 4.930426858702816
# Average total cost: 4.928793538222535
# Average total cost: 4.927166100868364
# Average total cost: 4.925544525449623
# Average total cost: 4.923928790851962
# Average total cost: 4.922318876037082
# Average total cost: 4.920714760042451
# Average total cost: 4.9191164219810695
# Average total cost: 4.917523841041141
# Average total cost: 4.915936996485851
# Average total cost: 4.914355867653075
# Average total cost: 4.912780433955112
# Average total cost: 4.91121067487841
# Average total cost: 4.909646569983313
# Average total cost: 4.908088098903787
# Average total cost: 4.90653524134715
# Average total cost: 4.904987977093813
# Average total cost: 4.903446285997033
# Average total cost: 4.901910147982609
# Average total cost: 4.900379543048668
# Average total cost: 4.898854451265367
# Average total cost: 4.897334852774656
# Average total cost: 4.8958207277900145
# Average total cost: 4.894312056596191
# Average total cost: 4.892808819548946
# Average total cost: 4.8913109970747914
# Average total cost: 4.889818569670748
# Average total cost: 4.888331517904089
# Average total cost: 4.88684982241208
# Average total cost: 4.8853734639017246
# Average total cost: 4.883902423149521
# Average total cost: 4.88243668100122
# Average total cost: 4.880976218371549
# Average total cost: 4.879521016243988
# Average total cost: 4.878071055670512
# Average total cost: 4.876626317771341
# Average total cost: 4.875186783734711
# Average total cost: 4.87375243481661
# Average total cost: 4.872323252340536
# Average total cost: 4.870899217697262
# Average total cost: 4.869480312344593
# Average total cost: 4.868066517807121
# Average total cost: 4.866657815675987
# Average total cost: 4.865254187608632
# Average total cost: 4.863855615328573
# Average total cost: 4.862462080625158
# Average total cost: 4.861073565353325
# Average total cost: 4.859690051433372
# Average total cost: 4.858311520850716
# Average total cost: 4.856937955655665
# Average total cost: 4.855569337963179
# Average total cost: 4.8542056499526405
# Average total cost: 4.852846873867618
# Average total cost: 4.851492992015638
# Average total cost: 4.850143986767961
# Average total cost: 4.8487998405593355
# Average total cost: 4.8474605358877865
# Average total cost: 4.84612605531437
# Average total cost: 4.844796381462971
# Average total cost: 4.843471497020046
# Average total cost: 4.842151384734427
# Average total cost: 4.8408360274170805
# Average total cost: 4.839525407940882
# Average total cost: 4.838219509240405
# Average total cost: 4.8369183143116805
# Average total cost: 4.835621806212
# Average total cost: 4.834329968059677
# Average total cost: 4.833042783033826
# Average total cost: 4.831760234374152
# Average total cost: 4.830482305380745
# Average total cost: 4.829208979413816
# Average total cost: 4.827940239893543
# Average total cost: 4.826676070299798
# Average total cost: 4.825416454171979
# Average total cost: 4.824161375108761
# Average total cost: 4.822910816767899
# Average total cost: 4.821664762866013
# Average total cost: 4.820423197178368
# Average total cost: 4.819186103538688
# Average total cost: 4.817953465838903
# Average total cost: 4.816725268028978
# Average total cost: 4.815501494116685
# Average total cost: 4.814282128167403
# Average total cost: 4.813067154303901
# Average total cost: 4.8118565567061395
# Average total cost: 4.810650319611067
# Average total cost: 4.809448427312395
# Average total cost: 4.808250864160423
# Average total cost: 4.807057614561819
# Average total cost: 4.805868662979406
# Average total cost: 4.8046839939319765
# Average total cost: 4.80350359199409
# Average total cost: 4.802327441795865
# Average total cost: 4.80115552802278
# Average total cost: 4.799987835415476
# Average total cost: 4.798824348769554
# Average total cost: 4.79766505293539
# Average total cost: 4.796509932817917
# Average total cost: 4.795358973376449
# Average total cost: 4.794212159624466
# Average total cost: 4.793069476629437
# Average total cost: 4.79193090951261
# Average total cost: 4.790796443448837
# Average total cost: 4.789666063666357
# Average total cost: 4.7885397554466165
# Average total cost: 4.787417504124084
# Average total cost: 4.786299295086056
# Average total cost: 4.785185113772449
# Average total cost: 4.784074945675636
# Average total cost: 4.78296877634024
# Average total cost: 4.781866591362952
# Average total cost: 4.780768376392355
# Average total cost: 4.779674117128694
# Average total cost: 4.778583799323757
# Average total cost: 4.7774974087806354
# Average total cost: 4.776414931353553
# Average total cost: 4.775336352947691
# Average total cost: 4.7742616595190075
# Average total cost: 4.773190837074033
# Average total cost: 4.772123871669706
# Average total cost: 4.771060749413198
# Average total cost: 4.770001456461704
# Average total cost: 4.768945979022286
# Average total cost: 4.767894303351698
# Average total cost: 4.766846415756183
# Average total cost: 4.765802302591317
# Average total cost: 4.764761950261813
# Average total cost: 4.763725345221363
# Average total cost: 4.762692473972447
# Average total cost: 4.761663323066167
# Average total cost: 4.7606378791020525
# Average total cost: 4.7596161287279255
# Iteration  450: Cost     4.76
# Average total cost: 4.758598058639682
# Average total cost: 4.757583655581143
# Average total cost: 4.756572906343875
# Average total cost: 4.755565797767039
# Average total cost: 4.754562316737174
# Average total cost: 4.753562450188065
# Average total cost: 4.752566185100569
# Average total cost: 4.751573508502424
# Average total cost: 4.750584407468102
# Average total cost: 4.749598869118619
# Average total cost: 4.7486168806214
# Average total cost: 4.747638429190076
# Average total cost: 4.746663502084347
# Average total cost: 4.745692086609787
# Average total cost: 4.744724170117707
# Average total cost: 4.7437597400049745
# Average total cost: 4.74279878371385
# Average total cost: 4.741841288731832
# Average total cost: 4.7408872425914845
# Average total cost: 4.739936632870271
# Average total cost: 4.738989447190422
# Average total cost: 4.738045673218729
# Average total cost: 4.737105298666416
# Average total cost: 4.736168311288971
# Average total cost: 4.7352346988859875
# Average total cost: 4.734304449301007
# Average total cost: 4.73337755042134
# Average total cost: 4.732453990177953
# Average total cost: 4.731533756545258
# Average total cost: 4.730616837541011
# Average total cost: 4.7297032212260985
# Average total cost: 4.72879289570443
# Average total cost: 4.72788584912275
# Average total cost: 4.726982069670518
# Average total cost: 4.726081545579716
# Average total cost: 4.725184265124724
# Average total cost: 4.724290216622141
# Average total cost: 4.723399388430679
# Average total cost: 4.7225117689509455
# Average total cost: 4.721627346625359
# Average total cost: 4.72074610993795
# Average total cost: 4.7198680474142325
# Average total cost: 4.718993147621053
# Average total cost: 4.7181213991664395
# Average total cost: 4.71725279069945
# Average total cost: 4.716387310910037
# Average total cost: 4.7155249485288735
# Average total cost: 4.714665692327246
# Average total cost: 4.713809531116865
# Average total cost: 4.712956453749759
# Average total cost: 4.712106449118097
# Average total cost: 4.711259506154068
# Average total cost: 4.710415613829714
# Average total cost: 4.709574761156817
# Average total cost: 4.708736937186723
# Average total cost: 4.707902131010218
# Average total cost: 4.70707033175738
# Average total cost: 4.706241528597455
# Average total cost: 4.705415710738677
# Average total cost: 4.704592867428175
# Average total cost: 4.703772987951789
# Average total cost: 4.702956061633963
# Average total cost: 4.702142077837589
# Average total cost: 4.701331025963876
# Average total cost: 4.700522895452207
# Average total cost: 4.699717675780004
# Average total cost: 4.698915356462592
# Average total cost: 4.6981159270530615
# Average total cost: 4.6973193771421275
# Average total cost: 4.696525696358009
# Average total cost: 4.695734874366266
# Average total cost: 4.694946900869704
# Average total cost: 4.694161765608201
# Average total cost: 4.6933794583586
# Average total cost: 4.692599968934568
# Average total cost: 4.691823287186456
# Average total cost: 4.69104940300118
# Average total cost: 4.690278306302077
# Average total cost: 4.689509987048791
# Average total cost: 4.68874443523711
# Average total cost: 4.687981640898881
# Average total cost: 4.687221594101834
# Average total cost: 4.6864642849494915
# Average total cost: 4.685709703581009
# Average total cost: 4.6849578401710685
# Average total cost: 4.684208684929743
# Average total cost: 4.683462228102363
# Average total cost: 4.682718459969403
# Average total cost: 4.6819773708463295
# Average total cost: 4.681238951083514
# Average total cost: 4.680503191066068
# Average total cost: 4.6797700812137455
# Average total cost: 4.6790396119808015
# Average total cost: 4.678311773855884
# Average total cost: 4.677586557361886
# Average total cost: 4.67686395305585
# Average total cost: 4.676143951528825
# Average total cost: 4.675426543405747
# Average total cost: 4.674711719345328
# Average total cost: 4.673999470039923
# Average total cost: 4.673289786215413
# Average total cost: 4.672582658631085
# Average total cost: 4.671878078079504
# Average total cost: 4.671176035386411
# Average total cost: 4.670476521410587
# Average total cost: 4.669779527043732
# Average total cost: 4.669085043210367
# Average total cost: 4.668393060867687
# Average total cost: 4.667703571005475
# Average total cost: 4.667016564645956
# Average total cost: 4.666332032843699
# Average total cost: 4.665649966685487
# Average total cost: 4.664970357290217
# Average total cost: 4.664293195808769
# Average total cost: 4.663618473423901
# Average total cost: 4.662946181350124
# Average total cost: 4.6622763108336
# Average total cost: 4.661608853152019
# Average total cost: 4.660943799614486
# Average total cost: 4.660281141561419
# Average total cost: 4.659620870364415
# Average total cost: 4.6589629774261585
# Average total cost: 4.658307454180304
# Average total cost: 4.657654292091348
# Average total cost: 4.657003482654544
# Average total cost: 4.656355017395771
# Average total cost: 4.655708887871438
# Average total cost: 4.655065085668368
# Average total cost: 4.654423602403678
# Average total cost: 4.653784429724685
# Average total cost: 4.6531475593088025
# Average total cost: 4.652512982863399
# Average total cost: 4.651880692125732
# Average total cost: 4.651250678862817
# Average total cost: 4.650622934871315
# Average total cost: 4.649997451977443
# Average total cost: 4.64937422203686
# Average total cost: 4.648753236934553
# Average total cost: 4.648134488584752
# Average total cost: 4.6475179689308
# Average total cost: 4.646903669945063
# Average total cost: 4.646291583628818
# Average total cost: 4.645681702012166
# Average total cost: 4.645074017153896
# Average total cost: 4.644468521141422
# Average total cost: 4.643865206090639
# Average total cost: 4.643264064145854
# Average total cost: 4.642665087479663
# Average total cost: 4.6420682682928565
# Average total cost: 4.6414735988143185
# Iteration  600: Cost     4.64
# Average total cost: 4.640881071300923
# Average total cost: 4.640290678037439
# Average total cost: 4.639702411336421
# Average total cost: 4.6391162635381065
# Average total cost: 4.638532227010339
# Average total cost: 4.637950294148439
# Average total cost: 4.637370457375127
# Average total cost: 4.636792709140406
# Average total cost: 4.636217041921486
# Average total cost: 4.635643448222669
# Average total cost: 4.635071920575257
# Average total cost: 4.634502451537444
# Average total cost: 4.633935033694242
# Average total cost: 4.633369659657367
# Average total cost: 4.632806322065147
# Average total cost: 4.632245013582419
# Average total cost: 4.631685726900461
# Average total cost: 4.631128454736849
# Average total cost: 4.630573189835416
# Average total cost: 4.630019924966111
# Average total cost: 4.629468652924938
# Average total cost: 4.628919366533841
# Average total cost: 4.6283720586406325
# Average total cost: 4.627826722118865
# Average total cost: 4.6272833498677794
# Average total cost: 4.626741934812183
# Average total cost: 4.626202469902376
# Average total cost: 4.625664948114038
# Average total cost: 4.625129362448163
# Average total cost: 4.62459570593095
# Average total cost: 4.6240639716137135
# Average total cost: 4.623534152572802
# Average total cost: 4.623006241909501
# Average total cost: 4.622480232749946
# Average total cost: 4.621956118245026
# Average total cost: 4.621433891570306
# Average total cost: 4.620913545925932
# Average total cost: 4.620395074536541
# Average total cost: 4.619878470651173
# Average total cost: 4.619363727543186
# Average total cost: 4.618850838510171
# Average total cost: 4.6183397968738555
# Average total cost: 4.617830595980022
# Average total cost: 4.617323229198419
# Average total cost: 4.6168176899226845
# Average total cost: 4.61631397157025
# Average total cost: 4.615812067582252
# Average total cost: 4.615311971423452
# Average total cost: 4.614813676582156
# Average total cost: 4.6143171765701245
# Average total cost: 4.613822464922478
# Average total cost: 4.61332953519764
# Average total cost: 4.612838380977224
# Average total cost: 4.612348995865971
# Average total cost: 4.611861373491644
# Average total cost: 4.611375507504967
# Average total cost: 4.6108913915795355
# Average total cost: 4.610409019411731
# Average total cost: 4.609928384720636
# Average total cost: 4.609449481247961
# Average total cost: 4.608972302757962
# Average total cost: 4.608496843037342
# Average total cost: 4.608023095895196
# Average total cost: 4.60755105516292
# Average total cost: 4.607080714694121
# Average total cost: 4.606612068364546
# Average total cost: 4.606145110072005
# Average total cost: 4.605679833736285
# Average total cost: 4.6052162332990765
# Average total cost: 4.60475430272389
# Average total cost: 4.604294035995975
# Average total cost: 4.603835427122255
# Average total cost: 4.603378470131233
# Average total cost: 4.602923159072921
# Average total cost: 4.602469488018765
# Average total cost: 4.602017451061565
# Average total cost: 4.601567042315396
# Average total cost: 4.601118255915542
# Average total cost: 4.600671086018401
# Average total cost: 4.600225526801421
# Average total cost: 4.599781572463033
# Average total cost: 4.599339217222544
# Average total cost: 4.598898455320108
# Average total cost: 4.598459281016607
# Average total cost: 4.598021688593604
# Average total cost: 4.597585672353254
# Average total cost: 4.597151226618243
# Average total cost: 4.596718345731695
# Average total cost: 4.596287024057118
# Average total cost: 4.595857255978323
# Average total cost: 4.5954290358993495
# Average total cost: 4.5950023582443835
# Average total cost: 4.594577217457711
# Average total cost: 4.594153608003616
# Average total cost: 4.593731524366331
# Average total cost: 4.593310961049949
# Average total cost: 4.592891912578359
# Average total cost: 4.592474373495181
# Average total cost: 4.592058338363686
# Average total cost: 4.591643801766726
# Average total cost: 4.591230758306667
# Average total cost: 4.590819202605311
# Average total cost: 4.5904091293038425
# Average total cost: 4.590000533062744
# Average total cost: 4.589593408561724
# Average total cost: 4.589187750499663
# Average total cost: 4.588783553594526
# Average total cost: 4.5883808125833205
# Average total cost: 4.587979522221998
# Average total cost: 4.587579677285392
# Average total cost: 4.58718127256718
# Average total cost: 4.586784302879762
# Average total cost: 4.586388763054257
# Average total cost: 4.585994647940377
# Average total cost: 4.585601952406394
# Average total cost: 4.585210671339057
# Average total cost: 4.584820799643549
# Average total cost: 4.584432332243385
# Average total cost: 4.584045264080383
# Average total cost: 4.583659590114559
# Average total cost: 4.583275305324111
# Average total cost: 4.582892404705296
# Average total cost: 4.582510883272416
# Average total cost: 4.582130736057724
# Average total cost: 4.581751958111355
# Average total cost: 4.581374544501293
# Average total cost: 4.580998490313271
# Average total cost: 4.580623790650736
# Average total cost: 4.580250440634761
# Average total cost: 4.579878435403997
# Average total cost: 4.579507770114605
# Average total cost: 4.5791384399401975
# Average total cost: 4.5787704400717635
# Average total cost: 4.578403765717619
# Average total cost: 4.5780384121033375
# Average total cost: 4.577674374471691
# Average total cost: 4.577311648082582
# Average total cost: 4.576950228212994
# Average total cost: 4.57659011015692
# Average total cost: 4.57623128922531
# Average total cost: 4.5758737607459805
# Average total cost: 4.5755175200636025
# Average total cost: 4.575162562539603
# Average total cost: 4.574808883552121
# Average total cost: 4.574456478495941
# Average total cost: 4.57410534278244
# Average total cost: 4.573755471839512
# Average total cost: 4.573406861111527
# Average total cost: 4.573059506059269
# Average total cost: 4.572713402159868
# Iteration  750: Cost     4.57
# Average total cost: 4.572368544906732
# Average total cost: 4.5720249298095235
# Average total cost: 4.57168255239407
# Average total cost: 4.571341408202299
# Average total cost: 4.571001492792232
# Average total cost: 4.570662801737848
# Average total cost: 4.570325330629093
# Average total cost: 4.569989075071802
# Average total cost: 4.569654030687622
# Average total cost: 4.569320193113978
# Average total cost: 4.568987558004013
# Average total cost: 4.568656121026516
# Average total cost: 4.568325877865883
# Average total cost: 4.567996824222056
# Average total cost: 4.567668955810469
# Average total cost: 4.567342268361973
# Average total cost: 4.567016757622818
# Average total cost: 4.566692419354561
# Average total cost: 4.566369249334025
# Average total cost: 4.5660472433532595
# Average total cost: 4.565726397219449
# Average total cost: 4.565406706754897
# Average total cost: 4.56508816779695
# Average total cost: 4.564770776197948
# Average total cost: 4.564454527825171
# Average total cost: 4.564139418560776
# Average total cost: 4.563825444301775
# Average total cost: 4.563512600959931
# Average total cost: 4.5632008844617475
# Average total cost: 4.562890290748408
# Average total cost: 4.5625808157756955
# Average total cost: 4.562272455513971
# Average total cost: 4.561965205948124
# Average total cost: 4.561659063077476
# Average total cost: 4.561354022915784
# Average total cost: 4.56105008149115
# Average total cost: 4.560747234845988
# Average total cost: 4.5604454790369635
# Average total cost: 4.560144810134944
# Average total cost: 4.559845224224966
# Average total cost: 4.559546717406147
# Average total cost: 4.559249285791658
# Average total cost: 4.55895292550868
# Average total cost: 4.558657632698342
# Average total cost: 4.558363403515663
# Average total cost: 4.558070234129523
# Average total cost: 4.557778120722592
# Average total cost: 4.557487059491293
# Average total cost: 4.557197046645755
# Average total cost: 4.556908078409752
# Average total cost: 4.556620151020653
# Average total cost: 4.5563332607293985
# Average total cost: 4.556047403800418
# Average total cost: 4.555762576511593
# Average total cost: 4.555478775154231
# Average total cost: 4.555195996032978
# Average total cost: 4.554914235465802
# Average total cost: 4.554633489783928
# Average total cost: 4.554353755331797
# Average total cost: 4.554075028467021
# Average total cost: 4.553797305560327
# Average total cost: 4.553520582995514
# Average total cost: 4.553244857169412
# Average total cost: 4.552970124491822
# Average total cost: 4.552696381385484
# Average total cost: 4.5524236242860185
# Average total cost: 4.5521518496418825
# Average total cost: 4.551881053914332
# Average total cost: 4.551611233577363
# Average total cost: 4.551342385117678
# Average total cost: 4.551074505034633
# Average total cost: 4.550807589840179
# Average total cost: 4.5505416360588615
# Average total cost: 4.550276640227711
# Average total cost: 4.550012598896252
# Average total cost: 4.549749508626435
# Average total cost: 4.549487365992581
# Average total cost: 4.549226167581371
# Average total cost: 4.548965909991763
# Average total cost: 4.548706589834976
# Average total cost: 4.548448203734425
# Average total cost: 4.548190748325696
# Average total cost: 4.547934220256495
# Average total cost: 4.547678616186597
# Average total cost: 4.547423932787805
# Average total cost: 4.5471701667439195
# Average total cost: 4.546917314750678
# Average total cost: 4.546665373515725
# Average total cost: 4.546414339758558
# Average total cost: 4.5461642102105015
# Average total cost: 4.545914981614642
# Average total cost: 4.545666650725799
# Average total cost: 4.545419214310491
# Average total cost: 4.545172669146868
# Average total cost: 4.544927012024698
# Average total cost: 4.544682239745305
# Average total cost: 4.544438349121537
# Average total cost: 4.5441953369777215
# Average total cost: 4.543953200149627
# Average total cost: 4.543711935484407
# Average total cost: 4.543471539840591
# Average total cost: 4.543232010088011
# Average total cost: 4.542993343107777
# Average total cost: 4.542755535792233
# Average total cost: 4.542518585044915
# Average total cost: 4.542282487780517
# Average total cost: 4.542047240924837
# Average total cost: 4.541812841414761
# Average total cost: 4.541579286198187
# Average total cost: 4.541346572234026
# Average total cost: 4.541114696492134
# Average total cost: 4.540883655953284
# Average total cost: 4.540653447609125
# Average total cost: 4.540424068462129
# Average total cost: 4.540195515525589
# Average total cost: 4.539967785823539
# Average total cost: 4.539740876390731
# Average total cost: 4.539514784272603
# Average total cost: 4.539289506525236
# Average total cost: 4.53906504021532
# Average total cost: 4.538841382420098
# Average total cost: 4.538618530227344
# Average total cost: 4.538396480735328
# Average total cost: 4.538175231052766
# Average total cost: 4.537954778298799
# Average total cost: 4.537735119602922
# Average total cost: 4.5375162521049965
# Average total cost: 4.537298172955166
# Average total cost: 4.537080879313846
# Average total cost: 4.536864368351685
# Average total cost: 4.536648637249518
# Average total cost: 4.536433683198327
# Average total cost: 4.536219503399223
# Average total cost: 4.536006095063397
# Average total cost: 4.535793455412083
# Average total cost: 4.53558158167652
# Average total cost: 4.5353704710979255
# Average total cost: 4.535160120927452
# Average total cost: 4.534950528426154
# Average total cost: 4.534741690864949
# Average total cost: 4.534533605524582
# Average total cost: 4.5343262696956135
# Average total cost: 4.534119680678329
# Average total cost: 4.533913835782765
# Average total cost: 4.533708732328637
# Average total cost: 4.5335043676453095
# Average total cost: 4.533300739071781
# Average total cost: 4.533097843956626
# Average total cost: 4.53289567965796
# Average total cost: 4.532694243543437
# Iteration  900: Cost     4.53
# Average total cost: 4.532493532990172
# Average total cost: 4.532293545384733
# Average total cost: 4.532094278123113
# Average total cost: 4.5318957286106665
# Average total cost: 4.53169789426211
# Average total cost: 4.531500772501459
# Average total cost: 4.531304360762016
# Average total cost: 4.53110865648632
# Average total cost: 4.530913657126132
# Average total cost: 4.530719360142385
# Average total cost: 4.530525763005162
# Average total cost: 4.530332863193652
# Average total cost: 4.5301406581961325
# Average total cost: 4.5299491455099234
# Average total cost: 4.529758322641358
# Average total cost: 4.529568187105754
# Average total cost: 4.529378736427377
# Average total cost: 4.529189968139409
# Average total cost: 4.529001879783918
# Average total cost: 4.5288144689118335
# Average total cost: 4.528627733082891
# Average total cost: 4.5284416698656305
# Average total cost: 4.52825627683734
# Average total cost: 4.52807155158404
# Average total cost: 4.527887491700443
# Average total cost: 4.527704094789921
# Average total cost: 4.527521358464492
# Average total cost: 4.527339280344756
# Average total cost: 4.527157858059903
# Average total cost: 4.526977089247652
# Average total cost: 4.526796971554226
# Average total cost: 4.5266175026343385
# Average total cost: 4.526438680151145
# Average total cost: 4.526260501776217
# Average total cost: 4.526082965189514
# Average total cost: 4.525906068079347
# Average total cost: 4.525729808142365
# Average total cost: 4.525554183083503
# Average total cost: 4.525379190615968
# Average total cost: 4.525204828461203
# Average total cost: 4.525031094348856
# Average total cost: 4.524857986016757
# Average total cost: 4.524685501210882
# Average total cost: 4.524513637685319
# Average total cost: 4.524342393202258
# Average total cost: 4.524171765531945
# Average total cost: 4.524001752452654
# Average total cost: 4.523832351750659
# Average total cost: 4.523663561220222
# Average total cost: 4.523495378663532
# Average total cost: 4.523327801890704
# Average total cost: 4.523160828719743
# Average total cost: 4.5229944569765115
# Average total cost: 4.522828684494694
# Average total cost: 4.522663509115791
# Average total cost: 4.52249892868907
# Average total cost: 4.522334941071547
# Average total cost: 4.52217154412796
# Average total cost: 4.522008735730736
# Average total cost: 4.521846513759958
# Average total cost: 4.521684876103358
# Average total cost: 4.521523820656273
# Average total cost: 4.521363345321613
# Average total cost: 4.5212034480098495
# Average total cost: 4.521044126638972
# Average total cost: 4.520885379134481
# Average total cost: 4.520727203429336
# Average total cost: 4.520569597463953
# Average total cost: 4.520412559186168
# Average total cost: 4.52025608655119
# Average total cost: 4.520100177521615
# Average total cost: 4.51994483006737
# Average total cost: 4.519790042165689
# Average total cost: 4.519635811801097
# Average total cost: 4.519482136965379
# Average total cost: 4.519329015657546
# Average total cost: 4.519176445883831
# Average total cost: 4.519024425657636
# Average total cost: 4.518872952999521
# Average total cost: 4.518722025937186
# Average total cost: 4.518571642505414
# Average total cost: 4.518421800746086
# Average total cost: 4.518272498708123
# Average total cost: 4.518123734447491
# Average total cost: 4.517975506027139
# Average total cost: 4.517827811517001
# Average total cost: 4.517680648993969
# Average total cost: 4.517534016541851
# Average total cost: 4.517387912251359
# Average total cost: 4.517242334220096
# Average total cost: 4.517097280552498
# Average total cost: 4.516952749359838
# Average total cost: 4.516808738760195
# Average total cost: 4.516665246878423
# Average total cost: 4.516522271846126
# Average total cost: 4.5163798118016425
# Average total cost: 4.516237864890021
# Average total cost: 4.5160964292629835
# Average total cost: 4.515955503078912
# Average total cost: 4.515815084502823
# Average total cost: 4.515675171706342
# Average total cost: 4.515535762867679
# Average total cost: 4.5153968561716065
# Average total cost: 4.515258449809438
# Average total cost: 4.515120541978997
# Average total cost: 4.514983130884609
# Average total cost: 4.514846214737052
# Average total cost: 4.514709791753551
# Average total cost: 4.514573860157764
# Average total cost: 4.514438418179744
# Average total cost: 4.514303464055911
# Average total cost: 4.514168996029046
# Average total cost: 4.514035012348255
# Average total cost: 4.5139015112689425
# Average total cost: 4.513768491052823
# Average total cost: 4.513635949967841
# Average total cost: 4.513503886288198
# Average total cost: 4.513372298294308
# Average total cost: 4.513241184272776
# Average total cost: 4.513110542516388
# Average total cost: 4.5129803713240655
# Average total cost: 4.51285066900086
# Average total cost: 4.512721433857946
# Average total cost: 4.512592664212555
# Average total cost: 4.512464358387999
# Average total cost: 4.512336514713613
# Average total cost: 4.5122091315247665
# Average total cost: 4.512082207162818
# Average total cost: 4.511955739975094
# Average total cost: 4.511829728314879
# Average total cost: 4.5117041705413925
# Average total cost: 4.511579065019769
# Average total cost: 4.511454410121006
# Average total cost: 4.511330204221995
# Average total cost: 4.511206445705468
# Average total cost: 4.511083132959975
# Average total cost: 4.51096026437987
# Average total cost: 4.510837838365307
# Average total cost: 4.5107158533221785
# Average total cost: 4.51059430766214
# Average total cost: 4.510473199802552
# Average total cost: 4.510352528166486
# Average total cost: 4.51023229118269
# Average total cost: 4.510112487285568
# Average total cost: 4.509993114915171
# Average total cost: 4.509874172517161
# Average total cost: 4.509755658542807
# Average total cost: 4.50963757144895
# Average total cost: 4.50951990969799
# Average total cost: 4.509402671757868
# Iteration 1050: Cost     4.51
# Average total cost: 4.509285856102039
# Average total cost: 4.509169461209462
# Average total cost: 4.509053485564568
# Average total cost: 4.508937927657258
# Average total cost: 4.508822785982858
# Average total cost: 4.508708059042124
# Average total cost: 4.508593745341216
# Average total cost: 4.508479843391655
# Average total cost: 4.508366351710347
# Average total cost: 4.508253268819524
# Average total cost: 4.508140593246749
# Average total cost: 4.508028323524885
# Average total cost: 4.507916458192075
# Average total cost: 4.507804995791743
# Average total cost: 4.507693934872547
# Average total cost: 4.5075832739883674
# Average total cost: 4.507473011698308
# Average total cost: 4.5073631465666555
# Average total cost: 4.507253677162868
# Average total cost: 4.507144602061552
# Average total cost: 4.507035919842459
# Average total cost: 4.506927629090447
# Average total cost: 4.50681972839547
# Average total cost: 4.5067122163525735
# Average total cost: 4.506605091561853
# Average total cost: 4.506498352628445
# Average total cost: 4.506391998162514
# Average total cost: 4.506286026779231
# Average total cost: 4.506180437098757
# Average total cost: 4.50607522774622
# Average total cost: 4.505970397351695
# Average total cost: 4.505865944550205
# Average total cost: 4.505761867981676
# Average total cost: 4.505658166290941
# Average total cost: 4.505554838127714
# Average total cost: 4.505451882146564
# Average total cost: 4.50534929700692
# Average total cost: 4.5052470813730245
# Average total cost: 4.505145233913951
# Average total cost: 4.50504375330354
# Average total cost: 4.504942638220435
# Average total cost: 4.504841887348026
# Average total cost: 4.504741499374441
# Average total cost: 4.504641472992546
# Average total cost: 4.504541806899903
# Average total cost: 4.5044424997987775
# Average total cost: 4.504343550396099
# Average total cost: 4.5042449574034595
# Average total cost: 4.504146719537084
# Average total cost: 4.504048835517842
# Average total cost: 4.503951304071184
# Average total cost: 4.5038541239271686
# Average total cost: 4.5037572938204224
# Average total cost: 4.503660812490135
# Average total cost: 4.503564678680032
# Average total cost: 4.503468891138366
# Average total cost: 4.503373448617895
# Average total cost: 4.503278349875874
# Average total cost: 4.503183593674036
# Average total cost: 4.503089178778568
# Average total cost: 4.502995103960105
# Average total cost: 4.502901367993708
# Average total cost: 4.502807969658853
# Average total cost: 4.502714907739411
# Average total cost: 4.502622181023631
# Average total cost: 4.502529788304132
# Average total cost: 4.502437728377874
# Average total cost: 4.50234600004616
# Average total cost: 4.502254602114602
# Average total cost: 4.502163533393121
# Average total cost: 4.5020727926959205
# Average total cost: 4.501982378841468
# Average total cost: 4.501892290652506
# Average total cost: 4.501802526956001
# Average total cost: 4.501713086583155
# Average total cost: 4.501623968369366
# Average total cost: 4.5015351711542415
# Average total cost: 4.501446693781558
# Average total cost: 4.501358535099273
# Average total cost: 4.501270693959467
# Average total cost: 4.5011831692183755
# Average total cost: 4.501095959736355
# Average total cost: 4.501009064377853
# Average total cost: 4.50092248201142
# Average total cost: 4.500836211509673
# Average total cost: 4.5007502517493
# Average total cost: 4.500664601611016
# Average total cost: 4.500579259979591
# Average total cost: 4.500494225743793
# Average total cost: 4.5004094977964115
# Average total cost: 4.500325075034205
# Average total cost: 4.500240956357912
# Average total cost: 4.500157140672241
# Average total cost: 4.500073626885831
# Average total cost: 4.499990413911263
# Average total cost: 4.499907500665022
# Average total cost: 4.499824886067514
# Average total cost: 4.499742569043017
# Average total cost: 4.499660548519692
# Average total cost: 4.499578823429556
# Average total cost: 4.499497392708477
# Average total cost: 4.499416255296161
# Average total cost: 4.499335410136121
# Average total cost: 4.499254856175682
# Average total cost: 4.499174592365959
# Average total cost: 4.499094617661846
# Average total cost: 4.4990149310220025
# Average total cost: 4.498935531408836
# Average total cost: 4.498856417788498
# Average total cost: 4.498777589130854
# Average total cost: 4.498699044409483
# Average total cost: 4.4986207826016615
# Average total cost: 4.498542802688363
# Average total cost: 4.498465103654209
# Average total cost: 4.498387684487495
# Average total cost: 4.49831054418015
# Average total cost: 4.498233681727738
# Average total cost: 4.498157096129444
# Average total cost: 4.498080786388059
# Average total cost: 4.498004751509955
# Average total cost: 4.497928990505097
# Average total cost: 4.497853502387002
# Average total cost: 4.497778286172755
# Average total cost: 4.497703340882971
# Average total cost: 4.497628665541798
# Average total cost: 4.497554259176892
# Average total cost: 4.497480120819419
# Average total cost: 4.497406249504034
# Average total cost: 4.497332644268858
# Average total cost: 4.497259304155493
# Average total cost: 4.497186228208988
# Average total cost: 4.49711341547782
# Average total cost: 4.4970408650139095
# Average total cost: 4.496968575872587
# Average total cost: 4.496896547112577
# Average total cost: 4.496824777795999
# Average total cost: 4.496753266988366
# Average total cost: 4.496682013758532
# Average total cost: 4.4966110171787195
# Average total cost: 4.496540276324487
# Average total cost: 4.496469790274731
# Average total cost: 4.496399558111664
# Average total cost: 4.496329578920791
# Average total cost: 4.4962598517909225
# Average total cost: 4.496190375814155
# Average total cost: 4.496121150085844
# Average total cost: 4.496052173704616
# Average total cost: 4.49598344577233
# Average total cost: 4.495914965394089
# Average total cost: 4.49584673167822
# Iteration 1200: Cost     4.50
# Average total cost: 4.495778743736256
# Average total cost: 4.495711000682939
# Average total cost: 4.495643501636183
# Average total cost: 4.495576245717105
# Average total cost: 4.495509232049967
# Average total cost: 4.495442459762186
# Average total cost: 4.495375927984337
# Average total cost: 4.495309635850109
# Average total cost: 4.495243582496324
# Average total cost: 4.4951777670629065
# Average total cost: 4.495112188692884
# Average total cost: 4.4950468465323645
# Average total cost: 4.494981739730536
# Average total cost: 4.49491686743965
# Average total cost: 4.49485222881501
# Average total cost: 4.494787823014972
# Average total cost: 4.494723649200905
# Average total cost: 4.494659706537212
# Average total cost: 4.494595994191309
# Average total cost: 4.494532511333591
# Average total cost: 4.494469257137471
# Average total cost: 4.494406230779307
# Average total cost: 4.4943434314384545
# Average total cost: 4.494280858297201
# Average total cost: 4.4942185105407875
# Average total cost: 4.494156387357403
# Average total cost: 4.494094487938134
# Average total cost: 4.494032811477004
# Average total cost: 4.493971357170925
# Average total cost: 4.4939101242197115
# Average total cost: 4.493849111826053
# Average total cost: 4.493788319195519
# Average total cost: 4.493727745536529
# Average total cost: 4.49366739006036
# Average total cost: 4.49360725198114
# Average total cost: 4.49354733051581
# Average total cost: 4.493487624884137
# Average total cost: 4.493428134308705
# Average total cost: 4.493368858014889
# Average total cost: 4.493309795230865
# Average total cost: 4.493250945187582
# Average total cost: 4.493192307118759
# Average total cost: 4.493133880260873
# Average total cost: 4.493075663853159
# Average total cost: 4.493017657137589
# Average total cost: 4.492959859358859
# Average total cost: 4.492902269764394
# Average total cost: 4.492844887604319
# Average total cost: 4.492787712131477
# Average total cost: 4.492730742601389
# Average total cost: 4.492673978272259
# Average total cost: 4.492617418404968
# Average total cost: 4.492561062263052
# Average total cost: 4.492504909112713
# Average total cost: 4.492448958222776
# Average total cost: 4.492393208864719
# Average total cost: 4.492337660312629
# Average total cost: 4.492282311843223
# Average total cost: 4.492227162735803
# Average total cost: 4.492172212272291
# Average total cost: 4.492117459737173
# Average total cost: 4.492062904417529
# Average total cost: 4.492008545602998
# Average total cost: 4.491954382585781
# Average total cost: 4.491900414660625
# Average total cost: 4.49184664112482
# Average total cost: 4.491793061278188
# Average total cost: 4.491739674423073
# Average total cost: 4.491686479864331
# Average total cost: 4.491633476909317
# Average total cost: 4.4915806648678895
# Average total cost: 4.491528043052386
# Average total cost: 4.491475610777625
# Average total cost: 4.491423367360894
# Average total cost: 4.491371312121932
# Average total cost: 4.491319444382941
# Average total cost: 4.491267763468547
# Average total cost: 4.49121626870583
# Average total cost: 4.49116495942427
# Average total cost: 4.491113834955785
# Average total cost: 4.4910628946346876
# Average total cost: 4.491012137797683
# Average total cost: 4.490961563783879
# Average total cost: 4.490911171934752
# Average total cost: 4.490860961594161
# Average total cost: 4.4908109321083165
# Average total cost: 4.490761082825792
# Average total cost: 4.490711413097507
# Average total cost: 4.490661922276715
# Average total cost: 4.490612609719008
# Average total cost: 4.490563474782287
# Average total cost: 4.490514516826772
# Average total cost: 4.490465735214987
# Average total cost: 4.4904171293117505
# Average total cost: 4.490368698484176
# Average total cost: 4.490320442101644
# Average total cost: 4.49027235953582
# Average total cost: 4.490224450160623
# Average total cost: 4.490176713352229
# Average total cost: 4.490129148489065
# Average total cost: 4.4900817549517935
# Average total cost: 4.490034532123305
# Average total cost: 4.4899874793887244
# Average total cost: 4.489940596135376
# Average total cost: 4.4898938817528
# Average total cost: 4.489847335632735
# Average total cost: 4.489800957169108
# Average total cost: 4.489754745758032
# Average total cost: 4.489708700797792
# Average total cost: 4.48966282168884
# Average total cost: 4.489617107833788
# Average total cost: 4.489571558637408
# Average total cost: 4.489526173506605
# Average total cost: 4.489480951850421
# Average total cost: 4.489435893080036
# Average total cost: 4.489390996608741
# Average total cost: 4.489346261851942
# Average total cost: 4.48930168822716
# Average total cost: 4.489257275153997
# Average total cost: 4.48921302205416
# Average total cost: 4.489168928351442
# Average total cost: 4.48912499347169
# Average total cost: 4.489081216842844
# Average total cost: 4.4890375978948835
# Average total cost: 4.48899413605986
# Average total cost: 4.488950830771858
# Average total cost: 4.488907681467005
# Average total cost: 4.488864687583457
# Average total cost: 4.488821848561393
# Average total cost: 4.488779163843021
# Average total cost: 4.488736632872537
# Average total cost: 4.488694255096154
# Average total cost: 4.488652029962077
# Average total cost: 4.488609956920499
# Average total cost: 4.488568035423583
# Average total cost: 4.488526264925481
# Average total cost: 4.488484644882306
# Average total cost: 4.488443174752119
# Average total cost: 4.488401853994953
# Average total cost: 4.488360682072769
# Average total cost: 4.488319658449471
# Average total cost: 4.4882787825909
# Average total cost: 4.48823805396481
# Average total cost: 4.488197472040883
# Average total cost: 4.4881570362906995
# Average total cost: 4.48811674618776
# Average total cost: 4.488076601207441
# Average total cost: 4.4880366008270265
# Average total cost: 4.487996744525673
# Average total cost: 4.487957031784419
# Iteration 1350: Cost     4.49
# Average total cost: 4.487917462086165
# Average total cost: 4.487878034915682
# Average total cost: 4.487838749759594
# Average total cost: 4.4877996061063685
# Average total cost: 4.487760603446324
# Average total cost: 4.48772174127161
# Average total cost: 4.487683019076203
# Average total cost: 4.4876444363559145
# Average total cost: 4.487605992608355
# Average total cost: 4.487567687332956
# Average total cost: 4.48752952003095
# Average total cost: 4.487491490205359
# Average total cost: 4.487453597361009
# Average total cost: 4.487415841004499
# Average total cost: 4.4873782206442
# Average total cost: 4.487340735790274
# Average total cost: 4.487303385954625
# Average total cost: 4.48726617065093
# Average total cost: 4.487229089394612
# Average total cost: 4.487192141702837
# Average total cost: 4.487155327094519
# Average total cost: 4.487118645090291
# Average total cost: 4.487082095212528
# Average total cost: 4.487045676985318
# Average total cost: 4.487009389934455
# Average total cost: 4.48697323358746
# Average total cost: 4.486937207473537
# Average total cost: 4.486901311123599
# Average total cost: 4.486865544070243
# Average total cost: 4.486829905847748
# Average total cost: 4.486794395992075
# Average total cost: 4.486759014040852
# Average total cost: 4.486723759533376
# Average total cost: 4.486688632010598
# Average total cost: 4.486653631015132
# Average total cost: 4.486618756091231
# Average total cost: 4.486584006784801
# Average total cost: 4.486549382643359
# Average total cost: 4.486514883216075
# Average total cost: 4.4864805080537415
# Average total cost: 4.486446256708759
# Average total cost: 4.4864121287351395
# Average total cost: 4.486378123688517
# Average total cost: 4.48634424112611
# Average total cost: 4.4863104806067335
# Average total cost: 4.486276841690803
# Average total cost: 4.486243323940305
# Average total cost: 4.4862099269188125
# Average total cost: 4.486176650191464
# Average total cost: 4.486143493324961
# Average total cost: 4.486110455887581
# Average total cost: 4.4860775374491455
# Average total cost: 4.486044737581024
# Average total cost: 4.486012055856135
# Average total cost: 4.485979491848933
# Average total cost: 4.485947045135408
# Average total cost: 4.4859147152930685
# Average total cost: 4.485882501900957
# Average total cost: 4.485850404539627
# Average total cost: 4.485818422791136
# Average total cost: 4.485786556239061
# Average total cost: 4.48575480446847
# Average total cost: 4.485723167065915
# Average total cost: 4.4856916436194645
# Average total cost: 4.485660233718653
# Average total cost: 4.485628936954484
# Average total cost: 4.485597752919455
# Average total cost: 4.4855666812075246
# Average total cost: 4.485535721414106
# Average total cost: 4.4855048731360725
# Average total cost: 4.485474135971758
# Average total cost: 4.4854435095209375
# Average total cost: 4.485412993384827
# Average total cost: 4.4853825871660735
# Average total cost: 4.485352290468771
# Average total cost: 4.485322102898418
# Average total cost: 4.485292024061953
# Average total cost: 4.485262053567723
# Average total cost: 4.485232191025479
# Average total cost: 4.485202436046396
# Average total cost: 4.485172788243023
# Average total cost: 4.485143247229333
# Average total cost: 4.485113812620666
# Average total cost: 4.485084484033761
# Average total cost: 4.485055261086734
# Average total cost: 4.4850261433990735
# Average total cost: 4.484997130591646
# Average total cost: 4.484968222286679
# Average total cost: 4.4849394181077535
# Average total cost: 4.484910717679821
# Average total cost: 4.484882120629174
# Average total cost: 4.484853626583452
# Average total cost: 4.484825235171639
# Average total cost: 4.484796946024052
# Average total cost: 4.484768758772342
# Average total cost: 4.484740673049485
# Average total cost: 4.4847126884897826
# Average total cost: 4.4846848047288494
# Average total cost: 4.484657021403618
# Average total cost: 4.484629338152314
# Average total cost: 4.484601754614484
# Average total cost: 4.484574270430968
# Average total cost: 4.484546885243897
# Average total cost: 4.484519598696685
# Average total cost: 4.484492410434043
# Average total cost: 4.484465320101953
# Average total cost: 4.484438327347678
# Average total cost: 4.484411431819746
# Average total cost: 4.484384633167955
# Average total cost: 4.484357931043358
# Average total cost: 4.484331325098273
# Average total cost: 4.484304814986267
# Average total cost: 4.484278400362154
# Average total cost: 4.484252080881994
# Average total cost: 4.484225856203081
# Average total cost: 4.484199725983951
# Average total cost: 4.484173689884361
# Average total cost: 4.484147747565297
# Average total cost: 4.48412189868897
# Average total cost: 4.484096142918808
# Average total cost: 4.484070479919438
# Average total cost: 4.484044909356718
# Average total cost: 4.484019430897684
# Average total cost: 4.48399404421059
# Average total cost: 4.483968748964878
# Average total cost: 4.483943544831182
# Average total cost: 4.483918431481318
# Average total cost: 4.483893408588292
# Average total cost: 4.483868475826282
# Average total cost: 4.483843632870647
# Average total cost: 4.483818879397901
# Average total cost: 4.483794215085735
# Average total cost: 4.483769639613
# Average total cost: 4.483745152659697
# Average total cost: 4.483720753906989
# Average total cost: 4.483696443037178
# Average total cost: 4.48367221973372
# Average total cost: 4.4836480836812
# Average total cost: 4.4836240345653495
# Average total cost: 4.483600072073022
# Average total cost: 4.483576195892218
# Average total cost: 4.4835524057120315
# Average total cost: 4.483528701222707
# Average total cost: 4.4835050821155855
# Average total cost: 4.48348154808312
# Average total cost: 4.483458098818879
# Average total cost: 4.48343473401754
# Average total cost: 4.483411453374868
# Average total cost: 4.483388256587726
# w,b found by gradient descent: 1.166362350335582 -3.63029143940436

# %% [markdown]
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b> w, b found by gradient descent<b></td>
#     <td> 1.16636235 -3.63029143940436</td>
#   </tr>
# </table>

# %% [markdown]
# We will now use the final parameters from gradient descent to plot the linear fit.
#
# Recall that we can get the prediction for a single example $f(x^{(i)})= wx^{(i)}+b$.
#
# To calculate the predictions on the entire dataset, we can loop through all the training examples and calculate the prediction for each example. This is shown in the code block below.

# %%
m = x_train.shape[0]
predicted = np.zeros(m)

for i in range(m):
    predicted[i] = w * x_train[i] + b

# %% [markdown]
# We will now plot the predicted values to see the linear fit.

# %%
# Plot the linear fit
plt.plot(x_train, predicted, c = "b")

# Create a scatter plot of the data. 
plt.scatter(x_train, y_train, marker='x', c='r') 

# Set the title
plt.title("Profits vs. Population per city")
# Set the y-axis label
plt.ylabel('Profit in $10,000')
# Set the x-axis label
plt.xlabel('Population of City in 10,000s')
# Out:
# Text(0.5, 0, 'Population of City in 10,000s')

# %% [markdown]
# Your final values of $w,b$ can also be used to make predictions on profits. Let's predict what the profit would be in areas of 35,000 and 70,000 people.
#
# - The model takes in population of a city in 10,000s as input.
#
# - Therefore, 35,000 people can be translated into an input to the model as `np.array([3.5])`
#
# - Similarly, 70,000 people can be translated into an input to the model as `np.array([7.])`

# %%
predict1 = 3.5 * w + b
print('For population = 35,000, we predict a profit of $%.2f' % (predict1*10000))

predict2 = 7.0 * w + b
print('For population = 70,000, we predict a profit of $%.2f' % (predict2*10000))
# Out:
# For population = 35,000, we predict a profit of $4519.77
# For population = 70,000, we predict a profit of $45342.45

# %% [markdown]
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b> For population = 35,000, we predict a profit of<b></td>
#     <td> $4519.77 </td>
#   </tr>
#
#   <tr>
#     <td> <b> For population = 70,000, we predict a profit of<b></td>
#     <td> $45342.45 </td>
#   </tr>
# </table>

# %% [markdown]
# **Congratulations on completing this practice lab on linear regression! Next week, you will create models to solve a different type of problem: classification. See you there!**

# %% [markdown]
# <details>
#   <summary><font size="2" color="darkgreen"><b>Please click here if you want to experiment with any of the non-graded code.</b></font></summary>
#     <p><i><b>Important Note: Please only do this when you've already passed the assignment to avoid problems with the autograder.</b></i>
#     <ol>
#         <li> On the notebook’s menu, click “View” > “Cell Toolbar” > “Edit Metadata”</li>
#         <li> Hit the “Edit Metadata” button next to the code cell which you want to lock/unlock</li>
#         <li> Set the attribute value for “editable” to:
#             <ul>
#                 <li> “true” if you want to unlock it </li>
#                 <li> “false” if you want to lock it </li>
#             </ul>
#         </li>
#         <li> On the notebook’s menu, click “View” > “Cell Toolbar” > “None” </li>
#     </ol>
#     <p> Here's a short demo of how to do the steps above:
#         <br>
#         <img src="https://lh3.google.com/u/0/d/14Xy_Mb17CZVgzVAgq7NCjMVBvSae3xO1" align="center" alt="unlock_cells.gif">
# </details>
